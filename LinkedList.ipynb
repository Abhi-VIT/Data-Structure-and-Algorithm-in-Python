# %% [markdown]
# # **Create a node**

# %%
# create a node
class node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %% [markdown]
# # **Linkedlist**

# %%
class LinkedList:
    def __init__(self):
        self.head = None
    def append(self, data):
        node_new = node(data)
        if not self.head:
            self.head = node_new
            return 
        last = self.head
        while last.next:
            last = last.next
        last.next = node_new
    def display(self):
        l = self.head
        while l:
            print(l.data, end = '->')
            l = l.next
        print("None")
    def insert_last(self,data):
        new_node = node(data)
        if not self.head:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node
    def insert_first(self, data):
        new_node = node(data)
        new_node.next = self.head
        self.head = new_node
    def insert_position(self, data, position):
        new_node = node(data)
        if position == 0:
            new_node.next = self.head
            self.haad = new_node
            return 
        current = self.head
        count = 0
        
        while current.next and count < position-1:
            current = current.next
            count += 1
        
        if current.next is None:
            print("Position is out of range")
            return
        new_node.next = current.next
        current.next = new_node

# %% [markdown]
# # **Execute**

# %%
ll = LinkedList()
ll.append(10)
ll.append(20)
ll.append(30)
ll.insert_last(40)
ll.insert_first(20)
ll.insert_position(100, 9)
ll.insert_position(80,2)
ll.display()
# Out:
# Position is out of range
# 20->10->80->20->30->40->None
