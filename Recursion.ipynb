# %%
def factorial(i):
    if i == 1:
        return 1
    return i*factorial(i-1)

print(factorial(5))
# Out:
# 120

# %%
print(factorial(22/7))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(factorial(22/7))
#
# Cell In[5], line 4, in factorial(i)
#       2 if i == 1:
#       3     return 1
# ----> 4 return i*factorial(i-1)
#
# Cell In[5], line 4, in factorial(i)
#       2 if i == 1:
#       3     return 1
# ----> 4 return i*factorial(i-1)
#
#     [... skipping similar frames: factorial at line 4 (2974 times)]
#
# Cell In[5], line 4, in factorial(i)
#       2 if i == 1:
#       3     return 1
# ----> 4 return i*factorial(i-1)
#
# RecursionError: maximum recursion depth exceeded
